# %% [markdown]
# predict the price of given area

# %%
import pandas as pd

# %% [markdown]
# Loading the Data

# %%
df=pd.read_csv("areaprice071.csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# spilitting the dataQ into dependent and independent variable

# %%
x=df[["area"]]

# %%
x
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
y=df.price

# %%
y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %% [markdown]
# Data visualization

# %%
import matplotlib.pyplot as plt

# %%
plt.title("Area & Price Graph")
plt.xlabel("\n Area")
plt.ylabel("\n Price")
plt.scatter(x,y,color="red",s=80)
plt.plot(x,p,color="green")
plt.show()

# %% [markdown]
# Applying simple linear regression

# %%
pip install scikit-learn

# %%
#import warnings
#warnings.filterwarnings("ignore")

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
x
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
p=model.predict(x)

# %%
p
# Out:
# array([533664.38356164, 587979.45205479, 615136.98630137, 669452.05479452,
#        723767.12328767])

# %%
model.predict([[5000]])
# Out:
# C:\Users\de\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
m=model.coef_

# %%
m
# Out:
# array([135.78767123])

# %%
c=model.intercept_

# %%
c
# Out:
# np.float64(180616.43835616432)

# %%
m*5000+c
# Out:
# array([859554.79452055])

# %%
a=int(input("enter area"))
print("price is :" ,model.predict([[a]])[0])

# %%
pip install pickle

# %%
import pickle

# %%
pickle.dump(model,open("areaprice.pkl","wb"))

# %%
pip install streamlit
# Out:
# ...
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/39/60/868371b6482ccd9ef423c6f62650066cf8271fdb2ee84f192695ad6b7a96/streamlit-1.51.0-py3-none-any.whl.metadata
#   Using cached streamlit-1.51.0-py3-none-any.whl.metadata (9.5 kB)
# ...
#   Obtaining dependency information for altair!=5.4.0,!=5.4.1,<6,>=4.0 from https://files.pythonhosted.org/packages/aa/f3/0b6ced594e51cc95d8c1fc1640d3623770d01e4969d29c0bd09945fafefa/altair-5.5.0-py3-none-any.whl.metadata
#   Using cached altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Obtaining dependency information for blinker<2,>=1.5.0 from https://files.pythonhosted.org/packages/10/cb/f2ad4230dc2eb1a74edf38f1a38b9b52277f75bef262d8908e60d957e13c/blinker-1.9.0-py3-none-any.whl.metadata
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# ...
